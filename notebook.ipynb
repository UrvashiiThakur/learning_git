# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\Data Science\clustring\clustering.csv")

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# ...

# %%
X= df[["LoanAmount","ApplicantIncome"]]

plt.xlabel('Annual income')
plt.scatter(X["ApplicantIncome"],X["LoanAmount"],c='black')
plt.ylabel('loan Amount (In Thousand)')
plt.show()

# %%
K= 3
Centroids = (X.sample(n=K))
plt.scatter(X["ApplicantIncome"],X["LoanAmount"],c='black')
plt.scatter(Centroids["ApplicantIncome"],Centroids["LoanAmount"],c='cyan')
plt.ylabel('loan Amount (In Thousand)')
plt.xlabel('Annual income')
plt.show()

# %%
diff = 1
while(diff!=0):
    XD = X
    for index,row_c in Centroids.iterrows():
        ED =[]
        for index2,row_d in XD.iterrows():
            d1 = (row_c["ApplicantIncome"],row_c["ApplicantIncome"])**2
            d2 = (row_c["LoanAmount"],row_c["LoanAmount"])**2
            d= np.sqrt(d1+d2)
            ED.append(d)
        X[i]=ED
        i=i+1

    C = []
    for index,row in X.iterrows():
        min_dist = row[1]
        pos=1
        for i in range(K):
            if row[i+1]<min_dist:
                min_dist = row[i+1]
                pos = i+1
        C.append(pos)
    X['cluster']=C
